# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt

# load IAM
f = np.load('../data/iam_arrays_1000_mode47.npz')
q = f['q']
pcd = f['pcd']

plt.figure()
#theory = a_factor[i, time_step]*pcd[:, i]
for k in range(100):
    theory = 0.057 * pcd[:, k]
    plt.plot(q, theory)
